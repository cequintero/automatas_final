# %% [markdown]
# <a href="https://colab.research.google.com/github/cequintero/automatas_final/blob/main/DefinicionFormal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Autómatas y Lenguajes Formales
# #Integrantes: Juan David Marín - Cesar Eduardo Quintero
# #Profesor: Luis Carlos Guayacan
# #Escuela de Ingeniería de Sistemas e Informática
# #Definición formal del autómata

# %%
from google.colab import files
from IPython.display import Image

uploaded = files.upload()
# Out:
#      <input type="file" id="files-7eaba448-00f2-4d13-ac60-66f58921f7ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7eaba448-00f2-4d13-ac60-66f58921f7ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving MT2.png to MT2.png

# %%
Image ('img1.png', width=800)

# %%
#Sea MT el autómata definido
MT = (Q, q0, F, Σ, Γ, B, δ)
#Conjunto de estados
Q = {q0 , q1 , q2 , q3 , q4 , q5 , q6 , q7 , q8 , q9 , q10 , q11 , q12}
#Estado inicial
q0 = q0
#Estados Finales
F = {q12}
#Alfabeto del autómata
Σ = {0, 1, #, *}
#Conjunto de símbolos de cinta
Γ = {0, 1, #, *, .}
#Simbolo para limpiar la cinta
B = .
#Transiciones
δ(q0, 1) = (q1, 1, R)
δ(q0, 0) = (q1, 0, R)
δ(q0, #)=(q8, #, R)
δ(q1, 1)=(q2, 1, R)
δ(q1, 0)=(q2, 0, R)
δ(q2, 1)=(q3, 1, R)
δ(q2, 0)=(q3, 0, R)
δ(q3, 1)=(q4, 1, R)
δ(q3, 0)=(q4, 0, R)
δ(q4, 1)=(q5, 1, R)
δ(q4, 0)=(q5, 0, R)
δ(q5, 1)=(q6, 1, R)
δ(q5, 0)=(q6, 0, R)
δ(q6, 1)=(q7, 1, R)
δ(q6, 0)=(q7, 0, R)
δ(q7, 1)=(q8, *, R)
δ(q7, 0)=(q8, *, R)
δ(q8, 1)=(q8, 1, R)
δ(q8, 0)=(q8, 0, R)
δ(q8, #)=(q9, #, R)
δ(q9, 1)=(q10, #, L)
δ(q9, 0)=(q11, #, L)
δ(q9, #)=(q9, #, R)
δ(q9, .)=(q12, ., L)
δ(q10, 1)=(q10, 1, L)
δ(q10, 0)=(q10, 0, L)
δ(q10, #)=(q10, #, L)
δ(q10, *)=(q0, 1, R)
δ(q11, 1)=(q11, 1, L)
δ(q11, 0)=(q11, 0, L)
δ(q11, #)=(q11, #, L)
δ(q11, *)=(q0, 0, R)

# %%
Image ('MT2.png', width=800)

# %%
#Sea MT el autómata definido
MT = (Q, q0, F, Σ, Γ, B, δ)
#Conjunto de estados
Q = {q0 , q1 , q2 , q3 , q4 , q5 , q6 , q7 , q8 , q9 , q10 , q11 , q12, q13, q14}
#Estado inicial
q0 = q0
#Estados Finales
F = {q14}
#Alfabeto del autómata
Σ = {0, 1, #, *}
#Conjunto de símbolos de cinta
Γ = {0, 1, #, *, .}
#Simbolo para limpiar la cinta
B = .
#Transiciones
δ(q0, 1)=(q1, 1, R)
δ(q0, 0)=(q1, 0, R)
δ(q0, #)=(q14, #, R)
δ(q1, 1)=(q2, 1, R)
δ(q1, 0)=(q2, 0, R)
δ(q2, 1)=(q3, 1, R)
δ(q2, 0)=(q3, 0, R)
δ(q3, 1)=(q4, 1, R)
δ(q3, 0)=(q4, 0, R)
δ(q4, 1)=(q5, 1, R)
δ(q4, 0)=(q5, 0, R)
δ(q5, 1)=(q6, 1, R)
δ(q5, 0)=(q6, 0, R)
δ(q6, 1)=(q7, 1, R)
δ(q6, 0)=(q7, 0, R)
δ(q7, 1)=(q9, *, R)
δ(q7, 0)=(q8, *, R)
δ(q8, 1)=(q8, 1, R)
δ(q8, 0)=(q8, 0, R)
δ(q8, #)=(q10, #, R)
δ(q9, 1)=(q9, 1, R)
δ(q9, 0)=(q9, 0, R)
δ(q9, #)=(q11, #, R)
δ(q10, 1)=(q10, 1, R)
δ(q10, 0)=(q10, 0, R)
δ(q10, .)=(q12, 0, L)
δ(q11, 1)=(q11, 1, R)
δ(q11, 0)=(q11, 0, R)
δ(q11, *)=(q13, 1, L)
δ(q12, 1)=(q12, 1, L)
δ(q12, 0)=(q11, 0, L)
δ(q12, #)=(q12, #, L)
δ(q12, *)=(q0, 0, R)
δ(q13, 1)=(q13, 1, L)
δ(q13, 0)=(q13, 0, L)
δ(q13, #)=(q13, #, L)
δ(q13, *)=(q0, 1, R)
